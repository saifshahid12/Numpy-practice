# %% [markdown]
# <a href="https://colab.research.google.com/github/saifshahid12/Numpy-practice/blob/main/Broadcasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# broadcasting use to scalar whole array
# add subtract arrays with different shapes
# perfom data without loop
import numpy as np
A = np.array([[1, 2, 3],
              [4, 5, 6]])

c = np.array([[10],
              [20]])

print(A + c)          # if both arrays dont have same values it also work then on it
# Out:
# [[11 12 13]
#  [24 25 26]]
